# %% [markdown]
# # Pandas

# %% [markdown]
# The pandas DataFrame is a structure that contains two-dimensional data and its corresponding labels.

# %% [markdown]
# Import libraries that are needed

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Games Sales.csv')

# %%
df.head()
# Out:
#                             Name  Sales     Series    Release  \
# 0  PlayerUnknown's Battlegrounds   42.0        NaN  12/1/2017
# 1                      Minecraft   33.0  Minecraft  11/1/2011
# 2                     Diablo III   20.0     Diablo   5/1/2012
# 3                    Garry's Mod   20.0        NaN  11/1/2006
# 4                       Terraria   17.2        NaN   5/1/2011
#
#                  Genre               Developer               Publisher
# 0        Battle royale            PUBG Studios                 Krafton
# 1    Sandbox, survival          Mojang Studios          Mojang Studios
# 2  Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 3              Sandbox       Facepunch Studios                   Valve
# 4     Action-adventure                Re-Logic                Re-Logic

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       177 non-null    object
#  1   Sales      177 non-null    float64
#  2   Series     141 non-null    object
#  3   Release    177 non-null    object
#  4   Genre      177 non-null    object
#  5   Developer  177 non-null    object
#  6   Publisher  177 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 9.8+ KB

# %%
df.notnull().sum()
# Out:
# Name         177
# Sales        177
# Series       141
# Release      177
# Genre        177
# Developer    177
# Publisher    177
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name          0
# Sales         0
# Series       36
# Release       0
# Genre         0
# Developer     0
# Publisher     0
# dtype: int64

# %%
df.tail()
# Out:
#                                      Name  Sales          Series    Release  \
# 172        Who Wants to Be a Millionaire?    1.0             NaN  11/1/1999
# 173  Wing Commander 3: Heart of the Tiger    1.0  Wing Commander  12/1/1994
# 174                            Zoo Tycoon    1.0      Zoo Tycoon  10/1/2001
# 175      StarCraft II: Heart of the Swarm    1.0       StarCraft   3/1/2013
# 176      StarCraft II: Legacy of the Void    1.0       StarCraft  11/1/2015
#
#                        Genre               Developer  \
# 172              Trivia game             Jellyvision
# 173  Space combat simulation          Origin Systems
# 174      Business simulation               Microsoft
# 175       Real-time strategy  Blizzard Entertainment
# 176       Real-time strategy  Blizzard Entertainment
#
#                       Publisher
# 172  Disney Interactive Studios
# 173             Electronic Arts
# 174             Blue Fang Games
# 175      Blizzard Entertainment
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Sales', 'Series', 'Release', 'Genre', 'Developer',
#        'Publisher'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=177, step=1)

# %%
# Menampilkan Informasi dari colimn-column yang berbentuk angka
df.describe()
# Out:
#             Sales
# count  177.000000
# mean     3.116949
# std      4.937466
# min      1.000000
# 25%      1.000000
# 50%      1.500000
# 75%      3.000000
# max     42.000000

# %%
# Menampilkan rerata column sales
df['Sales'].mean()
# Out:
# 3.116949152542373

# %%
# Menampilkan median column sales
df['Sales'].median()
# Out:
# 1.5

# %%
# Menampilkan modus column sales
df['Sales'].mode()[0]
# Out:
# 1.0

# %%
df[df['Sales'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Sales, Series, Release, Genre, Developer, Publisher]
# Index: []

# %%
df[['Name','Sales']]
# Out:
#                                      Name  Sales
# 0           PlayerUnknown's Battlegrounds   42.0
# 1                               Minecraft   33.0
# 2                              Diablo III   20.0
# 3                             Garry's Mod   20.0
# 4                                Terraria   17.2
# ..                                    ...    ...
# 172        Who Wants to Be a Millionaire?    1.0
# 173  Wing Commander 3: Heart of the Tiger    1.0
# 174                            Zoo Tycoon    1.0
# 175      StarCraft II: Heart of the Swarm    1.0
# 176      StarCraft II: Legacy of the Void    1.0
#
# [177 rows x 2 columns]

# %%
df.Sales.value_counts()
# Out:
# Sales
# 1.0     79
# 2.0     33
# 3.0      9
# 4.0      7
# 2.5      5
# 1.5      4
# 6.0      4
# 5.0      4
# 1.3      3
# 20.0     2
# 5.5      2
# 1.1      2
# 1.2      2
# 9.0      2
# 10.0     2
# 11.0     2
# 12.0     2
# 2.7      1
# 2.1      1
# 1.8      1
# 42.0     1
# 3.3      1
# 3.6      1
# 33.0     1
# 6.5      1
# 7.0      1
# 8.0      1
# 14.0     1
# 17.2     1
# 4.5      1
# Name: count, dtype: int64

# %%
df.Genre.unique()
# Out:
# array(['Battle royale', 'Sandbox,\xa0survival', 'Action role-playing',
#        'Sandbox', 'Action-adventure', 'MMORPG', 'First-person shooter',
#        'Real-time strategy', 'Life simulation',
#        'Construction and management simulation', 'Survival',
#        'Turn-based strategy,\xa04X', 'Vehicle simulation',
#        'Tactical shooter', 'City-building', 'God game', 'Educational',
#        'Graphic adventure', 'City-building game', 'Turn-based strategy',
#        'Adventure,\xa0puzzle', 'Role-playing game', 'Survival horror',
#        'Computer role-playing game', 'Third-person shooter',
#        'Racing game', 'Simulation', 'Fighting',
#        'Action-adventure,\xa0roguelike', 'Action-adventure,\xa0stealth',
#        'Compilation', 'RTS,\xa04X,\xa0Grand Strategy',
#        'Third-person shooter,\xa0survival horror',
#        'Action role-playing,\xa0hack and slash',
#        'Action role-playing game', 'Maze,\xa0arcade',
# ...

# %%
df.Genre.nunique()
# Out:
# 61

# %%
# memanggil column Sales value 5
df[df['Sales']==5]
# Out:
#                 Name  Sales      Series   Release          Genre  \
# 23  Cities: Skylines    5.0         NaN  3/1/2015  City-building
# 24      Guild Wars 2    5.0  Guild Wars  8/1/2012         MMORPG
# 25      SimCity 3000    5.0     SimCity  1/1/1999  City-building
# 26        The Forest    5.0         NaN  4/1/2018       Survival
#
#          Developer            Publisher
# 23  Colossal Order  Paradox Interactive
# 24        ArenaNet               NCsoft
# 25           Maxis      Electronic Arts
# 26  Endnight Games       Endnight Games

# %%
df[df['Release']< '1/1/2015']
# Out:
#               Name  Sales      Series   Release                 Genre  \
# 25    SimCity 3000    5.0     SimCity  1/1/1999         City-building
# 72         Magicka    2.0         NaN  1/1/2011      Action-adventure
# 77       SimCity 4    2.0     SimCity  1/1/2003         City-building
# 118  Duke Nukem 3D    1.0  Duke Nukem  1/1/1996  First-person shooter
# 162         Tetris    1.0      Tetris  1/1/1988                Puzzle
#
#                   Developer                  Publisher
# 25                    Maxis            Electronic Arts
# 72   Arrowhead Game Studios        Paradox Interactive
# 77                    Maxis  Electronic Arts (Windows)
# 118               3D Realms    GT Interactive Software
# 162       Spectrum HoloByte          Spectrum HoloByte

# %%
# memanggil colum age yang value nya lebih dari sama dengan 5
df[~(df['Sales']> 10)]
# Out:
#                                      Name  Sales                Series  \
# 10                              Fall Guys   10.0                   NaN
# 11                 RollerCoaster Tycoon 3   10.0  RollerCoaster Tycoon
# 12                              Half-Life    9.0             Half-Life
# 13                                   Rust    9.0                   NaN
# 14                         Civilization V    8.0          Civilization
# ..                                    ...    ...                   ...
# 172        Who Wants to Be a Millionaire?    1.0                   NaN
# 173  Wing Commander 3: Heart of the Tiger    1.0        Wing Commander
# 174                            Zoo Tycoon    1.0            Zoo Tycoon
# 175      StarCraft II: Heart of the Swarm    1.0             StarCraft
# 176      StarCraft II: Legacy of the Void    1.0             StarCraft
#
#        Release                                   Genre  \
# 10    8/1/2020                           Battle royale
# ...

# %%
df[(df['Sales']> 5) & (df['Release']== '11/1/2015')]
# Out:
# Empty DataFrame
# Columns: [Name, Sales, Series, Release, Genre, Developer, Publisher]
# Index: []

# %%
df[(df['Sales']> 5) | (df['Release']== '11/1/2015')]
# Out:
#                                  Name  Sales                Series    Release  \
# 0       PlayerUnknown's Battlegrounds   42.0                   NaN  12/1/2017
# 1                           Minecraft   33.0             Minecraft  11/1/2011
# 2                          Diablo III   20.0                Diablo   5/1/2012
# 3                         Garry's Mod   20.0                   NaN  11/1/2006
# 4                            Terraria   17.2                   NaN   5/1/2011
# 5                   World of Warcraft   14.0              Warcraft  11/1/2004
# 6                         Half-Life 2   12.0             Half-Life  11/1/2004
# 7            The Witcher 3: Wild Hunt   12.0           The Witcher   5/1/2015
# 8                           StarCraft   11.0             StarCraft   3/1/1998
# 9                            The Sims   11.0              The Sims   2/1/2000
# 10                          Fall Guys   10.0                   NaN   8/1/2020
# ...

# %%
df.shape
# Out:
# (177, 7)
